# %%
import math
import random

# %%
# random number function
def cust_Random(i,j):
    if(i==0 and j==0):
        return random.random()
    else: 
        return return random.randrange(i,f)

# %%
def round_ds(value, sd):
    if value == 0:
        return 0
    else:
        return round(value, sd - int(math.floor(math.log10(abs(value)))) - 1)

# %%
# generate random matrix
def random_mat(row_of_matrix,i_range_st,i_range_end,sd):
    matrix=[[ 0 for x in range(row_of_matrix)] for y in range(row_of_matrix)]
    for x in range(row_of_matrix): 
             for y in range(row_of_matrix): 
                 matrix[x][y] = round_ds(cust_Random(i_range_st,i_range_end,''),sd)
    return matrix

# %%
def xMatrix(row_of_matrix,i_range_st,i_range_end,sd):
    matrix=[[0 for x in range(1)]  for y in range(row_of_matrix) ]
    for y in range(row_of_matrix): 
        matrix[y][0] = round_ds(cust_Random(i_range_st,i_range_end,''),sd)
    return matrix

# %%
# without pivot
def f_elimination(matrix,xMatrix,sd,row_of_matrix):
    # Create augmented matrix
    for i in range(len(matrix)):
        matrix[i].append(xMatrix[i][0])
    print("Augumented matix : ",matrix)
    
    # forward elimination
    for totalLoops in range(row_of_matrix-1):  # for pivot element
        for row in range(len(matrix)):
            if(matrix[row][totalLoops]==0):
                pass
            else:
                col=matrix[row][totalLoops]
                for colm in range(len(matrix[row])):
                    if(row<=totalLoops or matrix[totalLoops][totalLoops] ==0):
                        pass
                    else:
                        matrix[row][colm]=round_ds((matrix[row][colm]-(col * (matrix[totalLoops][colm]/matrix[totalLoops][totalLoops]))) ,sd)

    
    return matrix

# %%
# partial pivoiting

# without pivioitng
def elimination_pivoting(matrix,xMatrix,sd,row_of_matrix):
    # Create augmented matrix
    for i in range(len(matrix)):
        matrix[i].append(xMatrix[i][0])
    print("Augumented : ",matrix)
    
    # start elimination forward style
    for totalLoops in range(row_of_matrix-1):  # for pivot element
        currentMax=matrix[totalLoops][totalLoops]
        j=totalLoops;
        for row in range(len(matrix)):
            if(abs(currentMax)<abs(matrix[row][totalLoops]) and row>totalLoops):
                currentMax=matrix[row][totalLoops]
                j=row
        if(j!=totalLoops):
            temp=matrix[totalLoops]
            matrix[totalLoops]=matrix[j]
            matrix[j]=temp
        for row in range(len(matrix)):
            if(matrix[row][totalLoops]==0):
                pass
            else:
                col=matrix[row][totalLoops]
                for colm in range(len(matrix[row])):
                    if(row<=totalLoops or matrix[totalLoops][totalLoops] ==0):
                        pass
                    else:
                        matrix[row][colm]=round_ds((matrix[row][colm]-(col * (matrix[totalLoops][colm]/matrix[totalLoops][totalLoops]))) ,sd)

    
    return matrix #Auguemented resultant from forward matrix

# %%
def back_elimination(matrix,xMatrix,sd,row_of_matrix):
    c=[[0 for x in range(1)]  for y in range(row_of_matrix) ];
    col_len=len(matrix[0])
    for x in reversed(range(row_of_matrix)):
        var_a=0;
        for j in reversed(range(col_len)):
            if(col_len-1==j):
                var_a=round_ds(matrix[x][j],sd)
            elif(x==j):
                var_a=round_ds(var_a/matrix[x][j],sd)
            elif(j<row_of_matrix and j>=x):
                 var_a = round_ds(var_a - matrix[x][j]*c[j][0],sd) 
        c[x][0]=var_a

    return c

# %%
def  gausianElimination(rowRangeStart,rowRangeEnd,i_range_st,i_range_end,sd):
        row_of_matrix =cust_Random(rowRangeStart,rowRangeEnd,'rank')
        matrix = random_mat(row_of_matrix,i_range_st,i_range_end,sd)
        x_mat = xMatrix(row_of_matrix,i_range_st,i_range_end,sd)
        print("c: ", x_mat)
        print("A:", matrix)
        without_Pivot_Matrix = f_elimination(matrix,x_mat,sd,row_of_matrix);
        pivot_Matrix = elimination_pivoting(matrix,x_mat,sd,row_of_matrix);
        with_pivot_matrix= back_elimination(pivot_Matrix,x_mat,sd,row_of_matrix)
        print("matrix with pivot",with_pivot_matrix)
        not_pivot=back_elimination(without_Pivot_Matrix,x_mat,sd,row_of_matrix)
        print("matrix without pivot",not_pivot)

# %%
gausianElimination(3,4,-9,9,5)
# Out:
# c:  [[6.5197], [-2.9706], [-7.5211], [-6.086], [1.9319], [-7.3594], [-1.4708], [-6.8954], [5.3304], [1.2748], [-1.1056], [-7.1597], [-4.6109], [7.1565], [-3.1342], [-7.1425], [5.8396], [-5.657], [5.5256], [7.4662], [4.9743], [5.2427], [-6.4134], [3.5759], [-4.3162], [2.6028], [3.9838], [2.4695], [1.1837], [-0.90981], [8.5112], [-2.6488], [-3.4424], [2.5709], [-8.2281], [6.094], [-1.5849], [3.5524], [-8.2532], [-2.4205], [4.3397], [-4.5762], [7.3986], [3.788], [-7.1459], [-8.2673], [4.2278], [-7.9265], [7.397], [5.6514], [-6.1884], [-0.47419], [3.6531], [0.067283], [-5.5907], [5.4919], [6.0612], [8.1406], [-2.6111], [3.8865], [-7.3006], [-1.4149], [-2.021], [-0.60004], [5.4976], [-8.2545], [0.35107], [2.2634], [-6.2699], [-1.4061], [4.3663], [-2.993], [0.71087], [-1.8847], [3.3645], [-3.7549], [2.8291], [7.1852], [1.9431], [-6.9166], [-2.8989], [1.4836], [0.739], [7.7528], [8.9629], [-8.6772], [5.5925], [-0.54924], [2.1226], [-5.2424], [7.4859], [8.7098], [5.0905], [1.0682], [4.1248],
# ...
